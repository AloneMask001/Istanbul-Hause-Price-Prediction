# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
veri = pd.read_csv('ev_verisi.csv')
veri.head(2)
# Out:
#    İlan_Numarası İlan_Güncelleme_Tarihi Kategorisi  Brüt_Metrekare  \
# 0           2003         02 Şubat 2022    Satılık              190
# 1            166          14 Ocak 2022    Satılık              300
#
#    Binanın_Yaşı  Binanın_Kat_Sayısı   Kullanım_Durumu Yatırıma_Uygunluk  \
# 0         5-10                   20  Kiracı Oturuyor        Bilinmiyor
# 1  21 Ve Üzeri                    2  Kiracı Oturuyor        Bilinmiyor
#
#   Eşya_Durumu Banyo_Sayısı  ... Site_İçerisinde Takas  Fiyat_Durumu    Fiyatı  \
# 0         Yok           2   ...           Hayır   Var  Genel Fiyat   18000000
# 1         Yok           3   ...           Hayır   Var  Genel Fiyat    8500000
#
#           İl        İlçe                Mahalle           yaka Yaşam_endeksi  \
# 0  İstanbul    Beşiktaş    Nisbetiye Mahallesi   Avrupa Yakası         0.911
# 1  İstanbul    Beşiktaş         Akat Mahallesi   Avrupa Yakası         0.911
#
#      Nüfus
# 0  178.938
# 1  178.938
#
# [2 rows x 27 columns]

# %%
pd.isnull(veri)
# Out:
#       İlan_Numarası  İlan_Güncelleme_Tarihi  Kategorisi  Brüt_Metrekare  \
# 0             False                   False       False           False
# 1             False                   False       False           False
# 2             False                   False       False           False
# 3             False                   False       False           False
# 4             False                   False       False           False
# ...             ...                     ...         ...             ...
# 2978          False                   False       False           False
# 2979          False                   False       False           False
# 2980          False                   False       False           False
# 2981          False                   False       False           False
# 2982          False                   False       False           False
#
#       Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  Yatırıma_Uygunluk  \
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   İlan_Numarası           2983 non-null   int64
#  1   İlan_Güncelleme_Tarihi  2983 non-null   object
#  2   Kategorisi              2983 non-null   object
#  3   Brüt_Metrekare          2983 non-null   int64
#  4   Binanın_Yaşı            2983 non-null   object
#  5   Binanın_Kat_Sayısı      2983 non-null   int64
#  6   Kullanım_Durumu         2983 non-null   object
#  7   Yatırıma_Uygunluk       2983 non-null   object
#  8   Eşya_Durumu             2983 non-null   object
#  9   Banyo_Sayısı            2983 non-null   object
#  10  İlan_Oluşturma_Tarihi   2983 non-null   object
#  11  Türü                    2983 non-null   object
#  12  Net_Metrekare           2983 non-null   int64
#  13  Oda_Sayısı              2983 non-null   object
# ...

# %%
veri.describe()
# Out:
#        İlan_Numarası  Brüt_Metrekare  Binanın_Kat_Sayısı  Net_Metrekare  \
# count    2983.000000     2983.000000         2983.000000    2983.000000
# mean     1491.000000      169.342943            8.669796     145.346631
# std       861.262252      373.361202            7.091614     370.482565
# min         0.000000       35.000000            1.000000       1.000000
# 25%       745.500000      100.000000            4.000000      84.000000
# 50%      1491.000000      130.000000            5.000000     106.000000
# 75%      2236.500000      180.000000           11.000000     150.000000
# max      2982.000000    13500.000000           44.000000   13499.000000
#
#              Fiyatı  Yaşam_endeksi        Nüfus
# count  2.983000e+03    2983.000000  2983.000000
# mean   5.221566e+06       0.212120   512.159881
# std    3.716717e+07       0.401684   206.819574
# min    1.690000e+05      -0.194000   178.938000
# 25%    8.700000e+05      -0.152000   398.122000
# ...

# %%
# %matplotlib inline

# %%
column_names = list(veri.columns.values)
for column_name in column_names:
    
    all_column_uniqe = (veri[column_name].unique()).size
    
    print(f'{column_name} sütununda {all_column_uniqe} adet benzersiz değer vardır.')
    print()
    
print('done')
# Out:
# İlan_Numarası sütununda 2983 adet benzersiz değer vardır.
#
# İlan_Güncelleme_Tarihi sütununda 135 adet benzersiz değer vardır.
#
# Kategorisi sütununda 1 adet benzersiz değer vardır.
#
# Brüt_Metrekare sütununda 261 adet benzersiz değer vardır.
#
# Binanın_Yaşı sütununda 9 adet benzersiz değer vardır.
#
# Binanın_Kat_Sayısı sütununda 33 adet benzersiz değer vardır.
#
# Kullanım_Durumu sütununda 3 adet benzersiz değer vardır.
#
# Yatırıma_Uygunluk sütununda 4 adet benzersiz değer vardır.
#
# Eşya_Durumu sütununda 2 adet benzersiz değer vardır.
#
# Banyo_Sayısı sütununda 12 adet benzersiz değer vardır.
#
# İlan_Oluşturma_Tarihi sütununda 182 adet benzersiz değer vardır.
#
# Türü sütununda 1 adet benzersiz değer vardır.
#
# Net_Metrekare sütununda 239 adet benzersiz değer vardır.
#
# Oda_Sayısı sütununda 24 adet benzersiz değer vardır.
#
# Bulunduğu_Kat sütununda 43 adet benzersiz değer vardır.
#
# Isıtma_Tipi sütununda 5 adet benzersiz değer vardır.
#
# ...

# %%
veri['Fiyat_Durumu']
# Out:
# 0       Genel Fiyat
# 1       Genel Fiyat
# 2       Genel Fiyat
# 3       Genel Fiyat
# 4       Genel Fiyat
#             ...
# 2978    Genel Fiyat
# 2979    Genel Fiyat
# 2980    Genel Fiyat
# 2981    Genel Fiyat
# 2982    Genel Fiyat
# Name: Fiyat_Durumu, Length: 2983, dtype: object

# %%
veri = veri.drop(['İlan_Numarası','İlan_Güncelleme_Tarihi','Kategorisi','Brüt_Metrekare','İlan_Oluşturma_Tarihi','Türü','Takas','İl'], axis = 1)

veri.head()
# Out:
#    Binanın_Yaşı  Binanın_Kat_Sayısı        Kullanım_Durumu Yatırıma_Uygunluk  \
# 0         5-10                   20       Kiracı Oturuyor        Bilinmiyor
# 1  21 Ve Üzeri                    2       Kiracı Oturuyor        Bilinmiyor
# 2  21 Ve Üzeri                    3  Mülk Sahibi Oturuyor        Bilinmiyor
# 3         5-10                    4       Kiracı Oturuyor        Bilinmiyor
# 4  21 Ve Üzeri                    2  Mülk Sahibi Oturuyor        Bilinmiyor
#
#   Eşya_Durumu Banyo_Sayısı  Net_Metrekare Oda_Sayısı Bulunduğu_Kat  \
# 0         Yok           2             168       4+1        1. Kat
# 1         Yok           3             270       5+1    Bahçe Katı
# 2         Yok           2             320       5+2     Düz Giriş
# 3         Yok           3             400       6+2     Düz Giriş
# 4         Yok           1             140       3+1        1. Kat
#
#   Isıtma_Tipi Krediye_Uygunluk Site_İçerisinde  Fiyat_Durumu    Fiyatı  \
# ...

# %%
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Binanın_Yaşı        2983 non-null   object
#  1   Binanın_Kat_Sayısı  2983 non-null   int64
#  2   Kullanım_Durumu     2983 non-null   object
#  3   Yatırıma_Uygunluk   2983 non-null   object
#  4   Eşya_Durumu         2983 non-null   object
#  5   Banyo_Sayısı        2983 non-null   object
#  6   Net_Metrekare       2983 non-null   int64
#  7   Oda_Sayısı          2983 non-null   object
#  8   Bulunduğu_Kat       2983 non-null   object
#  9   Isıtma_Tipi         2983 non-null   object
#  10  Krediye_Uygunluk    2983 non-null   object
#  11  Site_İçerisinde     2983 non-null   object
#  12  Fiyat_Durumu        2983 non-null   object
#  13  Fiyatı              2983 non-null   int64
#  14  İlçe                2983 non-null   object
# ...

# %%
veri = veri.drop(['Eşya_Durumu','Fiyat_Durumu'], axis = 1)
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2983 entries, 0 to 2982
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Binanın_Yaşı        2983 non-null   object
#  1   Binanın_Kat_Sayısı  2983 non-null   int64
#  2   Kullanım_Durumu     2983 non-null   object
#  3   Yatırıma_Uygunluk   2983 non-null   object
#  4   Banyo_Sayısı        2983 non-null   object
#  5   Net_Metrekare       2983 non-null   int64
#  6   Oda_Sayısı          2983 non-null   object
#  7   Bulunduğu_Kat       2983 non-null   object
#  8   Isıtma_Tipi         2983 non-null   object
#  9   Krediye_Uygunluk    2983 non-null   object
#  10  Site_İçerisinde     2983 non-null   object
#  11  Fiyatı              2983 non-null   int64
#  12  İlçe                2983 non-null   object
#  13  Mahalle             2983 non-null   object
#  14  yaka                2983 non-null   object
# ...

# %%
#Obje veri tipinde olanları çektik.
object_cols = veri.select_dtypes(include='object').columns.tolist()

for column in object_cols:
    print(column)
    print(veri[column].unique())
# Out:
# Binanın_Yaşı
# ['5-10 ' '21 Ve Üzeri ' '16-20 ' '0 (Yeni) ' '4 ' '2 ' '1 ' '11-15 ' '3 ']
# Kullanım_Durumu
# ['Kiracı Oturuyor ' 'Mülk Sahibi Oturuyor ' 'Boş ']
# Yatırıma_Uygunluk
# ['Bilinmiyor ' 'Hayır ' 'Yatırıma Uygun ' 'Evet ']
# Banyo_Sayısı
# ['2 ' '3 ' '1 ' '4 ' '5 ' 'Yok ' 'Var ' '6+ ' 'Genel Fiyat ' '28 M2 '
#  '1075 ' '15 ']
# Oda_Sayısı
# ['4+1 ' '5+1 ' '5+2 ' '6+2 ' '3+1 ' '2+1 ' '2.5+1 ' '1+1 ' '6+1 ' '4+2 '
#  '1 Oda ' '8+ Oda ' '7+1 ' '3.5+1 ' '4.5+1 ' '3+2 ' '2+2 ' 'Stüdyo '
#  '5+3 ' '1.5+1 ' '7+2 ' '6+4 ' '2+0 ' '6+3 ']
# Bulunduğu_Kat
# ['1. Kat ' 'Bahçe Katı ' 'Düz Giriş ' '6. Kat ' '8. Kat ' '2. Kat '
#  'Çatı Katı ' '4. Kat ' '3. Kat ' 'Yüksek Giriş ' '11. Kat ' '5. Kat '
#  '16. Kat ' '7. Kat ' '15. Kat ' 'Villa Tipi ' '17. Kat ' '10. Kat '
#  '9. Kat ' '30-40. Kat ' 'Kot 1 (-1). Kat ' '21. Kat ' '23. Kat '
#  '14. Kat ' '24. Kat ' 'Müstakil ' '22. Kat ' '12. Kat ' '18. Kat '
#  '30. Kat ' '19. Kat ' '20. Kat ' 'Kot 3 (-3). Kat ' 'Çatı Dubleks '
# ...

# %%
banyo_verisi = veri['Banyo_Sayısı'].head(10)
banyo_verisi
# Out:
# 0    2
# 1    3
# 2    2
# 3    3
# 4    1
# 5    1
# 6    4
# 7    1
# 8    1
# 9    2
# Name: Banyo_Sayısı, dtype: object

# %%
for column in object_cols:
    veri[column] = veri[column].str.strip()
print("done")
veri
# Out:
# done
#      Binanın_Yaşı  Binanın_Kat_Sayısı       Kullanım_Durumu Yatırıma_Uygunluk  \
# 0            5-10                  20       Kiracı Oturuyor        Bilinmiyor
# 1     21 Ve Üzeri                   2       Kiracı Oturuyor        Bilinmiyor
# 2     21 Ve Üzeri                   3  Mülk Sahibi Oturuyor        Bilinmiyor
# 3            5-10                   4       Kiracı Oturuyor        Bilinmiyor
# 4     21 Ve Üzeri                   2  Mülk Sahibi Oturuyor        Bilinmiyor
# ...           ...                 ...                   ...               ...
# 2978  21 Ve Üzeri                   4       Kiracı Oturuyor        Bilinmiyor
# 2979        16-20                   4       Kiracı Oturuyor        Bilinmiyor
# 2980        16-20                   4       Kiracı Oturuyor        Bilinmiyor
# 2981  21 Ve Üzeri                   3  Mülk Sahibi Oturuyor        Bilinmiyor
# 2982         5-10                   2       Kiracı Oturuyor        Bilinmiyor
#
# ...

# %%
veri['Binanın_Yaşı']
# Out:
# 0              5-10
# 1       21 Ve Üzeri
# 2       21 Ve Üzeri
# 3              5-10
# 4       21 Ve Üzeri
#            ...
# 2978    21 Ve Üzeri
# 2979          16-20
# 2980          16-20
# 2981    21 Ve Üzeri
# 2982           5-10
# Name: Binanın_Yaşı, Length: 2983, dtype: object

# %%
veri['Banyo_Sayısı'] = veri['Banyo_Sayısı'].apply(pd.to_numeric, errors='coerce')
veri['Banyo_Sayısı']
# Out:
# 0       2.0
# 1       3.0
# 2       2.0
# 3       3.0
# 4       1.0
#        ...
# 2978    5.0
# 2979    1.0
# 2980    3.0
# 2981    4.0
# 2982    3.0
# Name: Banyo_Sayısı, Length: 2983, dtype: float64

# %%
veri['Banyo_Sayısı'] = veri['Banyo_Sayısı'].fillna(veri['Banyo_Sayısı'].mean())
pd.isnull(veri['Banyo_Sayısı']).unique()
# Out:
# array([False])

# %%
veri['Banyo_Sayısı'].astype('int')
# Out:
# 0       2
# 1       3
# 2       2
# 3       3
# 4       1
#        ..
# 2978    5
# 2979    1
# 2980    3
# 2981    4
# 2982    3
# Name: Banyo_Sayısı, Length: 2983, dtype: int64

# %%
veri['Bulunduğu_Kat'].unique()
# Out:
# array(['1. Kat', 'Bahçe Katı', 'Düz Giriş', '6. Kat', '8. Kat', '2. Kat',
#        'Çatı Katı', '4. Kat', '3. Kat', 'Yüksek Giriş', '11. Kat',
#        '5. Kat', '16. Kat', '7. Kat', '15. Kat', 'Villa Tipi', '17. Kat',
#        '10. Kat', '9. Kat', '30-40. Kat', 'Kot 1 (-1). Kat', '21. Kat',
#        '23. Kat', '14. Kat', '24. Kat', 'Müstakil', '22. Kat', '12. Kat',
#        '18. Kat', '30. Kat', '19. Kat', '20. Kat', 'Kot 3 (-3). Kat',
#        'Çatı Dubleks', '13. Kat', '25. Kat', '26. Kat', 'Kot 2 (-2). Kat',
#        'Tam Bodrum', '10-20. Kat', '28. Kat', '27. Kat', '29. Kat'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
import re

# %%
#burası Kat sayısını numeric değere çeviren yer.
def kat_cevirici (kat_girdisi):
    
    ozel_kat_degerler = {
    'Bahçe Katı': 0, 'Düz Giriş': 0, 'Yüksek Giriş': 0,
    'Tam Bodrum': -1, 'Kot 1 (-1). Kat': -1,
    'Kot 2 (-2). Kat': -2, 'Kot 3 (-3). Kat': -3,
    '30-40. Kat': 35, '10-20. Kat': 15,
    'Villa Tipi': 2, 'Müstakil': 2,
    'Çatı Katı': 'CATI', 'Çatı Dubleks': 'CATI'
}
    kat_sayısı_hesaplama = re.search(r'\d+', str(kat_girdisi))
    
    if kat_girdisi in ozel_kat_degerler:
        return ozel_kat_degerler.get(kat_girdisi)
    
    elif kat_sayısı_hesaplama:
        return int(kat_sayısı_hesaplama.group())
        
    
    
veri['Bulunduğu_Kat'] = veri['Bulunduğu_Kat'].apply(kat_cevirici)

max_kat = veri[veri['Bulunduğu_Kat'] != 'CATI']['Bulunduğu_Kat'].max()

veri.loc[veri['Bulunduğu_Kat'] == 'CATI', 'Bulunduğu_Kat'] = max_kat

# %%
veri['Bulunduğu_Kat'].unique()
#Verilerin noktalı görünme sebebi float olarak işlenmesi Nan -> float döndürür.
# Out:
# array([1, 0, 6, 8, 2, 35, 4, 3, 11, 5, 16, 7, 15, 17, 10, 9, -1, 21, 23,
#        14, 24, 22, 12, 18, 30, 19, 20, -3, 13, 25, 26, -2, 28, 27, 29],
#       dtype=object)

# %%
veri['Bulunduğu_Kat'] = veri['Bulunduğu_Kat'].astype('int')
print('done')
# Out:
# done

# %%
veri['Bulunduğu_Kat'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2983 entries, 0 to 2982
# Series name: Bulunduğu_Kat
# Non-Null Count  Dtype
# --------------  -----
# 2983 non-null   int64
# dtypes: int64(1)
# memory usage: 23.4 KB

# %%
veri.loc[veri['Banyo_Sayısı'] > 10, 'Banyo_Sayısı'] = veri['Banyo_Sayısı'].mean()

veri['Banyo_Sayısı'].unique()
# Out:
# array([2.        , 3.        , 1.        , 4.        , 5.        ,
#        2.04049844, 2.04049844])

# %%
veri['Banyo_Sayısı'] = veri['Banyo_Sayısı'].astype('int')

# %%
veri['Banyo_Sayısı'].unique()
# Out:
# array([2, 3, 1, 4, 5])

# %%
veri['Binanın_Yaşı'].unique()
# Out:
# array(['5-10', '21 Ve Üzeri', '16-20', '0 (Yeni)', '4', '2', '1', '11-15',
#        '3'], dtype=object)

# %%
#Bina sayısı numeric yapma kısmı.

def bina_kat_numeric(bina_kat):
    ozel_kat_değerler_bina = {'5-10' : 7, '21 Ve Üzeri' : 25, '16-20' : 18, 
                     '0 (Yeni)': 0, '11-15': 13
                    }

    regex_bina_kat_cevirici = re.search(r'\d+', str(bina_kat))

    if bina_kat in ozel_kat_değerler_bina:
        return ozel_kat_değerler_bina.get(bina_kat)
    elif regex_bina_kat_cevirici:
        return int(regex_bina_kat_cevirici.group())

veri['Binanın_Yaşı'] = veri['Binanın_Yaşı'].apply(bina_kat_numeric)

# %%
veri['Binanın_Yaşı'].unique()
# Out:
# array([ 7, 25, 18,  0,  4,  2,  1, 13,  3])

# %%
veri['Kullanım_Durumu'].unique()
# Out:
# array(['Kiracı Oturuyor', 'Mülk Sahibi Oturuyor', 'Boş'], dtype=object)

# %%
le = LabelEncoder()

# %%
veri['Kullanım_Durumu'] = le.fit_transform(veri['Kullanım_Durumu'])

# %%
veri['Kullanım_Durumu'].unique()
# Out:
# array([1, 2, 0])

# %%
veri['Yatırıma_Uygunluk'].unique()
# Out:
# array(['Bilinmiyor', 'Hayır', 'Yatırıma Uygun', 'Evet'], dtype=object)

# %%
veri['Yatırıma_Uygunluk'] = le.fit_transform(veri['Yatırıma_Uygunluk'])

# %%
veri['Yatırıma_Uygunluk'].unique()
# Out:
# array([0, 2, 3, 1])

# %%
veri['Krediye_Uygunluk'].unique()
# Out:
# array(['KREDIYE UYGUN', 'Krediye Uygun Değil', 'Bilinmiyor'], dtype=object)

# %%
veri
# Out:
#       Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  Yatırıma_Uygunluk  \
# 0                7                  20                1                  0
# 1               25                   2                1                  0
# 2               25                   3                2                  0
# 3                7                   4                1                  0
# 4               25                   2                2                  0
# ...            ...                 ...              ...                ...
# 2978            25                   4                1                  0
# 2979            18                   4                1                  0
# 2980            18                   4                1                  0
# 2981            25                   3                2                  0
# 2982             7                   2                1                  0
#
# ...

# %%
veri['Krediye_Uygunluk'] = le.fit_transform(veri['Krediye_Uygunluk'])

# %%
veri['Krediye_Uygunluk'].unique()
# Out:
# array([1, 2, 0])

# %%
veri['Isıtma_Tipi'].unique()
# Out:
# array(['Klimalı', 'Doğalgaz', 'Sobalı', 'Yerden Isıtma', 'Isıtma Yok'],
#       dtype=object)

# %%
veri['Isıtma_Tipi'] = le.fit_transform(veri['Isıtma_Tipi'])

# %%
veri['Isıtma_Tipi'].unique()
# Out:
# array([2, 0, 3, 4, 1])

# %%
veri['Site_İçerisinde'].unique()
# Out:
# array(['Hayır', 'Evet'], dtype=object)

# %%
veri['Site_İçerisinde'] = le.fit_transform(veri['Site_İçerisinde'])

# %%
veri['Site_İçerisinde'].unique()
# Out:
# array([1, 0])

# %%
ham_veri = pd.read_csv('ev_verisi.csv')

# %%
veri_ham = pd.read_csv('ev_verisi.csv')
veri['İlçe_Mahalle'] = veri_ham['İlçe'] + ' - ' + veri_ham['Mahalle']
string_İlçe_mahalle = veri['İlçe_Mahalle'] 

#smoothing value
m = 15
global_mean = veri["Fiyatı"].mean()

veri.loc[:, 'string_İlçe_mahalle'] = string_İlçe_mahalle
mahalle_ort = veri.groupby('string_İlçe_mahalle')['Fiyatı'].agg(["mean", "count"])
#smoothing part
mahalle_ort["encoding"] = (mahalle_ort["count"] * mahalle_ort["mean"] + m * global_mean) / (m + mahalle_ort["count"])
veri['İlçe_Mahalle_target'] = veri['string_İlçe_mahalle'].map(mahalle_ort["encoding"])


#target encoding.
#To avoid overfitting i will implement smoothing using sigmoid function.
#First detecting ilçe mahalle combinations where less than 15. If it is less than five i make them to close to mean.
#a = np.where(veri['İlçe_Mahalle_target'].value_counts() < 10)
"""
(array([ 94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106,
        107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119,
        120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132,
        133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145,
        146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158,
        159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171,
        172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184,
        185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197,
        198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210,
        211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223,
        224, 225, 226]),)
"""
mahalle_ort[mahalle_ort["count"] < 10]
# Out:
#                                                       mean  count  \
# string_İlçe_mahalle
# Avcılar  -  Firuzköy Mahallesi                5.826667e+06      3
# Avcılar  -  Yeşilkent Mahallesi               8.350000e+05      1
# Bahçelievler  -  Cumhuriyet Mahallesi         5.758000e+05      5
# Bahçelievler  -  Fevzi Çakmak Mahallesi       7.383333e+05      6
# Bahçelievler  -  Kocasinan Merkez Mahallesi   1.705556e+06      9
# ...                                                    ...    ...
# Sarıyer  -  Uskumruköy Mahallesi              6.466667e+06      3
# Sarıyer  -  Yeni Mahallesi                    5.325000e+06      2
# Sarıyer  -  Yeniköy Mahallesi                 1.033000e+08      3
# Sarıyer  -  Çayırbaşı Mahallesi               9.000333e+05      3
# Şişli  -  Levent Mahallesi                    5.766667e+06      3
#
#                                                   encoding
# string_İlçe_mahalle
# Avcılar  -  Firuzköy Mahallesi                5.322416e+06
# ...

# %%
veri = veri.drop(['İlçe_Mahalle'], axis = 1)

# %%
veri.columns
# Out:
# Index(['Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
#        'Yatırıma_Uygunluk', 'Banyo_Sayısı', 'Net_Metrekare', 'Oda_Sayısı',
#        'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
#        'Fiyatı', 'İlçe', 'Mahalle', 'yaka', 'Yaşam_endeksi', 'Nüfus',
#        'string_İlçe_mahalle', 'İlçe_Mahalle_target'],
#       dtype='object')

# %%
veri = veri.drop(['string_İlçe_mahalle'], axis=1)

# %%
veri.columns
# Out:
# Index(['Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
#        'Yatırıma_Uygunluk', 'Banyo_Sayısı', 'Net_Metrekare', 'Oda_Sayısı',
#        'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
#        'Fiyatı', 'İlçe', 'Mahalle', 'yaka', 'Yaşam_endeksi', 'Nüfus',
#        'İlçe_Mahalle_target'],
#       dtype='object')

# %%
veri['İlçe_Mahalle_target'].unique()
# Out:
# array([ 6028194.93317203, 11109311.81095653, 15639393.91274917,
#        20953249.56481465,  6333282.78209856,  6645749.08127537,
#        13211154.60217092,  7035446.49805035,  8212452.6082174 ,
#         8501235.97173456,  9269116.11543189,  9556860.19238649,
#        13199015.1082174 , 10718568.39527437, 13326671.84355023,
#         5808023.02204556,  5369028.43899745, 21129311.81095653,
#         4963967.7164348 ,  5051467.7164348 ,  5137415.74794204,
#         6545749.08127537,  5312415.74794204,  3374681.3170593 ,
#         3032953.10378969,  3124905.90547827,  3598859.33851827,
#         2440232.96584348,  2317096.50746704,  2780313.56890597,
#         3186559.1300704 ,  4947405.2164348 ,  5322415.74794204,
#         3782059.33851827,  2370386.48043315,  3229249.44876522,
#         3719412.32447638,  3285809.77458472,  2492840.07367993,
#         3048702.5769674 ,  3940642.06966461,  3210671.3582174 ,
#         3903061.81095653,  4060124.17314784,  4939640.1082174 ,
# ...

# %%
veri.columns
# Out:
# Index(['Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
#        'Yatırıma_Uygunluk', 'Banyo_Sayısı', 'Net_Metrekare', 'Oda_Sayısı',
#        'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
#        'Fiyatı', 'İlçe', 'Mahalle', 'yaka', 'Yaşam_endeksi', 'Nüfus',
#        'İlçe_Mahalle_target'],
#       dtype='object')

# %%
veri
# Out:
#       Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  Yatırıma_Uygunluk  \
# 0                7                  20                1                  0
# 1               25                   2                1                  0
# 2               25                   3                2                  0
# 3                7                   4                1                  0
# 4               25                   2                2                  0
# ...            ...                 ...              ...                ...
# 2978            25                   4                1                  0
# 2979            18                   4                1                  0
# 2980            18                   4                1                  0
# 2981            25                   3                2                  0
# 2982             7                   2                1                  0
#
# ...

# %%
veri['yaka'].unique()
# Out:
# array(['Avrupa Yakası', 'Anadolu Yakası'], dtype=object)

# %%
veri['yaka'] = le.fit_transform(veri['yaka'])

# %%
veri['yaka'].unique()
# Out:
# array([1, 0])

# %%
veri['Oda_Sayısı'].unique()
# Out:
# array(['4+1', '5+1', '5+2', '6+2', '3+1', '2+1', '2.5+1', '1+1', '6+1',
#        '4+2', '1 Oda', '8+ Oda', '7+1', '3.5+1', '4.5+1', '3+2', '2+2',
#        'Stüdyo', '5+3', '1.5+1', '7+2', '6+4', '2+0', '6+3'], dtype=object)

# %%
#'1 Oda', '8+ Oda', 'Stüdyo'

# %%
oda_map = {
    'Stüdyo': 1,
    '1 Oda': 1,
    '2+0': 2,
    '1+1': 2,
    '1.5+1': 3,
    '2+1': 3,
    '2+2': 4,
    '2.5+1': 4,
    '3+1': 4,
    '3+2': 5,
    '3.5+1': 5,
    '4+1': 5,
    '4+2': 6,
    '4.5+1': 6,
    '5+1': 6,
    '5+2': 7,
    '5+3': 8,
    '6+1': 7,
    '6+2': 8,
    '6+3': 9,
    '6+4': 10,
    '7+1': 8,
    '7+2': 9,
    '8+ Oda': 10,
}

veri['Oda_Sayısı'] = veri['Oda_Sayısı'].map(oda_map)

# %%
veri['Oda_Sayısı'].value_counts()
# Out:
# Oda_Sayısı
# 3     1120
# 4      892
# 5      318
# 2      258
# 6      194
# 7       90
# 8       39
# 1       38
# 10      28
# 9        6
# Name: count, dtype: int64

# %%
veri.dtypes
# Out:
# Binanın_Yaşı             int64
# Binanın_Kat_Sayısı       int64
# Kullanım_Durumu          int64
# Yatırıma_Uygunluk        int64
# Banyo_Sayısı             int64
# Net_Metrekare            int64
# Oda_Sayısı               int64
# Bulunduğu_Kat            int64
# Isıtma_Tipi              int64
# Krediye_Uygunluk         int64
# Site_İçerisinde          int64
# Fiyatı                   int64
# İlçe                    object
# Mahalle                 object
# yaka                     int64
# Yaşam_endeksi          float64
# Nüfus                  float64
# İlçe_Mahalle_target    float64
# dtype: object

# %%
veri = veri[veri['Fiyatı'] <= 50000000]

# %%
veri = veri[veri['Bulunduğu_Kat'] <= veri['Binanın_Kat_Sayısı']]

# %%
veri.loc[:, 'kat_oran'] = veri['Bulunduğu_Kat'] / veri['Binanın_Kat_Sayısı'].replace(0, 1)

# %%
x = veri[['Binanın_Yaşı', 'Binanın_Kat_Sayısı', 'Kullanım_Durumu',
       'Yatırıma_Uygunluk', 'Banyo_Sayısı', 'Net_Metrekare', 'Oda_Sayısı',
       'Bulunduğu_Kat', 'Isıtma_Tipi', 'Krediye_Uygunluk', 'Site_İçerisinde',
        'yaka', 'Yaşam_endeksi', 'Nüfus', 'İlçe_Mahalle_target','kat_oran']]
y = np.log1p(veri['Fiyatı'])

# Fiyat dağılımını düzelt, uç değerleri sıkıştır-----np.log1p(veri['Fiyatı'])----*

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 42)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from xgboost import XGBRegressor

best_xgb = XGBRegressor(
    subsample=0.7, n_estimators=500, min_child_weight=5,
    max_depth=6, learning_rate=0.01, gamma=0.3,
    colsample_bytree=0.8, random_state=42, n_jobs=-1
)
best_xgb.fit(x_train, y_train)

y_pred_log = best_xgb.predict(x_test)
y_pred_gercek = np.expm1(y_pred_log)
# İkisi de log scale — hiç expm1 yok
print(f"R²: {r2_score(y_test, y_pred_log):.4f}")

# Gerçek fiyat MAE için
print(f"MAE: {mean_absolute_error(np.expm1(y_test), np.expm1(y_pred_log)):,.0f}")
# Out:
# R²: 0.7654
# MAE: 1,302,128

# %%
"""
from sklearn.ensemble import RandomForestRegressor
rfregressor = RandomForestRegressor(
    
    n_estimators=300,
    random_state=42,
    oob_score=True,
    max_depth = 25,
    min_samples_leaf = 2,
    max_features="sqrt"
)

rfregressor.fit(x_train, y_train)

# Out of Bag Error is a method used to estimate the prediction error of Random Forests.
it gaved 0.58 r^2
"""
# Out:
# '\nfrom sklearn.ensemble import RandomForestRegressor\nrfregressor = RandomForestRegressor(\n\n    n_estimators=300,\n    random_state=42,\n    oob_score=True,\n    max_depth = 25,\n    min_samples_leaf = 2,\n    max_features="sqrt"\n)\n\nrfregressor.fit(x_train, y_train)\n\n# Out of Bag Error is a method used to estimate the prediction error of Random Forests.\nit gaved 0.58 r^2\n'

# %%
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(best_xgb, x_train, y_train, cv=5, scoring='r2')
print(f"CV R²: {cv_scores.mean():.4f} ± {cv_scores.std():.4f}")
# Out:
# CV R²: 0.7618 ± 0.0190

# %%
# rfregressor.feature_importances_ → best_xgb.feature_importances_
feature_importance = pd.Series(best_xgb.feature_importances_, index=x.columns)
feature_importance.sort_values(ascending=False)
# Out:
# Yaşam_endeksi          0.306411
# Banyo_Sayısı           0.217917
# İlçe_Mahalle_target    0.084391
# Nüfus                  0.068793
# Net_Metrekare          0.065986
# Oda_Sayısı             0.044074
# Binanın_Kat_Sayısı     0.038366
# Binanın_Yaşı           0.028485
# yaka                   0.024288
# kat_oran               0.022506
# Bulunduğu_Kat          0.021970
# Isıtma_Tipi            0.020963
# Krediye_Uygunluk       0.017758
# Yatırıma_Uygunluk      0.016702
# Kullanım_Durumu        0.013878
# Site_İçerisinde        0.007513
# dtype: float32

# %%
veri
# Out:
#       Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  Yatırıma_Uygunluk  \
# 0                7                  20                1                  0
# 1               25                   2                1                  0
# 2               25                   3                2                  0
# 3                7                   4                1                  0
# 4               25                   2                2                  0
# ...            ...                 ...              ...                ...
# 2978            25                   4                1                  0
# 2979            18                   4                1                  0
# 2980            18                   4                1                  0
# 2981            25                   3                2                  0
# 2982             7                   2                1                  0
#
# ...

# %%
veri['kat_oran'].unique()
# Out:
# array([ 0.05      ,  0.        ,  0.5       ,  1.        ,  0.88888889,
#         0.4       ,  0.8       ,  0.33333333,  0.66666667,  0.14285714,
#         0.2       ,  0.6       ,  0.25      ,  0.42857143,  0.28571429,
#         0.35294118,  0.31818182,  0.51724138,  0.13636364,  0.83333333,
#         0.16666667,  0.69230769, -0.2       , -0.16666667,  0.7       ,
#         0.26666667,  0.85185185,  0.75      ,  0.07142857,  0.22727273,
#         0.17391304,  0.26086957,  0.71428571,  0.04545455,  0.23333333,
#         0.76666667,  0.60869565,  0.34782609,  0.85714286,  0.73333333,
#         0.63333333, -0.6       ,  0.4375    ,  0.68      ,  0.55555556,
#         0.18181818,  0.125     ,  0.375     ,  0.03333333,  0.41176471,
#         0.41666667,  0.64285714,  0.53333333,  0.52941176,  0.625     ,
#         0.95833333,  0.91666667,  0.76      ,  0.72727273,  0.35714286,
#         0.59259259,  0.90909091,  0.46666667,  0.57142857,  0.27272727,
# ...

# %%
x_test
# Out:
#       Binanın_Yaşı  Binanın_Kat_Sayısı  Kullanım_Durumu  Yatırıma_Uygunluk  \
# 2484             0                   5                0                  0
# 2517             1                  28                2                  0
# 2406             2                   4                0                  0
# 823              3                  24                1                  0
# 1683             0                  12                0                  0
# ...            ...                 ...              ...                ...
# 2940             0                  17                1                  0
# 2342             7                   4                0                  0
# 2268             0                   5                0                  0
# 1125             0                   6                2                  0
# 572              4                   5                0                  0
#
# ...

# %%
y_test.head()
# Out:
# 2484    14.880222
# 2517    14.731802
# 2406    14.711599
# 823     14.571633
# 1683    13.457407
# Name: Fiyatı, dtype: float64

# %%
y_test.describe()
# Out:
# count    584.000000
# mean      14.457912
# std        0.979072
# min       12.037660
# 25%       13.737550
# 50%       14.276076
# 75%       15.082458
# max       17.599700
# Name: Fiyatı, dtype: float64

# %%
m_0_2_arası_ev_veri = veri[veri['Fiyatı'] < 2000000]

m_2_10_arası_ev_veri = veri[(veri['Fiyatı'] > 2000000) & (veri['Fiyatı'] < 10000000)]

m_10_üstü_ev_veri  = veri[ 10000000 <= veri['Fiyatı']]

ev_classification = [m_0_2_arası_ev_veri, m_2_10_arası_ev_veri,
                     m_10_üstü_ev_veri]

for i in ev_classification:
    print(f'{len(i)} adet daire vardır.')
# Out:
# 1662 adet daire vardır.
# 1012 adet daire vardır.
# 226 adet daire vardır.

# %%
y_test_gercek = np.expm1(y_test)
y_prediction_series = pd.Series(y_pred_gercek, index=y_test.index)

mask_2    = (y_test_gercek <= 2000000)
mask_2_10 = (y_test_gercek > 2000000) & (y_test_gercek <= 10000000)
mask_10   = (y_test_gercek > 10000000)

print(f'0-2M MAE  : {mean_absolute_error(y_test_gercek[mask_2], y_prediction_series[mask_2]):,.0f}')
print(f'2-10M MAE : {mean_absolute_error(y_test_gercek[mask_2_10], y_prediction_series[mask_2_10]):,.0f}')
print(f'10M+ MAE  : {mean_absolute_error(y_test_gercek[mask_10], y_prediction_series[mask_10]):,.0f}')
# Out:
# 0-2M MAE  : 317,535
# 2-10M MAE : 1,602,999
# 10M+ MAE  : 8,205,367

# %%
# Genel grafik
plt.figure(figsize=(15, 6)) 
plt.scatter(y_test_gercek, y_prediction_series, color='#88c999')
plt.plot([y_test_gercek.min(), y_test_gercek.max()],
         [y_test_gercek.min(), y_test_gercek.max()],
         color='black')
plt.xlabel('Gerçek Veriler')
plt.ylabel('Tahmin Verileri')
plt.grid(True)
plt.title('Ev fiyat tahmini(gerçek-tahmin) karşılaştırması[TÜM]')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(15, 6)) 
plt.scatter(y_test_gercek[mask_2], y_prediction_series[mask_2], color='#88c999')

plt.plot([y_test_gercek[mask_2].min(), 2000000],
         [y_test_gercek[mask_2].min(), 2000000],
         color='black')

plt.xlabel('Gerçek Fiyat (TL)')
plt.ylabel('Tahmin Fiyat (TL)')
plt.title('[0-2M] arası evlerin gerçek-tahmin karşılaştırması')
plt.grid()
plt.show()
plt.tight_layout()
